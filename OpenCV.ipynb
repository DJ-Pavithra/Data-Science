# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/content/sample_data/NCAT.jpg')
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
grey_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(img.shape)
# Out:
# (1600, 720, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(rgb_img)

# %%
plt.imshow(grey_img,cmap='gray')

# %%
crop_img=rgb_img[200:1400,0:800,:]
plt.imshow(crop_img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(719.5), np.float64(1199.5), np.float64(-0.5))

# %%
#TOTAL PIXELS:
total_pix= crop_img.shape[0]*crop_img.shape[1]
print(total_pix)
# Out:
# 864000

# %%
#RESIZE
resize_img=cv2.resize(crop_img,(1000,1000))
plt.imshow(resize_img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(999.5), np.float64(999.5), np.float64(-0.5))
